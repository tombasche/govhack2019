# %%
import pandas as pd
import numpy as np
import arrow
import matplotlib

# %%
air_csv = pd.read_csv("/Users/elliottlovell/Dropbox/Learning/Coding/Repositories/govhack/Air_Quality_Monitoring_Live_Data__Daily_.csv")
air_csv["DateTime"] = pd.to_datetime(air_csv["DateTime"])
air_csv.set_index("DateTime", inplace=True)

air_month = air_csv.resample("BMS").mean()

air_csv.plot()
