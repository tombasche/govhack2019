# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Average_Passenger_Boardings_By_Service_Type_2017-18.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-52778ce8fbbb> in <module>
# ----> 1 df = pd.read_csv("Average_Passenger_Boardings_By_Service_Type_2017-18.csv").groupby(['Fiscal Month']).sum().plot().show
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
df = df.groupby(['Fiscal Month']).sum()

# %%
df.plot().show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-86cb451031cf> in <module>
# ----> 1 df.plot().show()
#
# AttributeError: 'AxesSubplot' object has no attribute 'show'

# %%
df.to_csv("passengers_per_month.csv")
